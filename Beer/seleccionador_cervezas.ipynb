# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import streamlit as st
import ipywidgets as widgets
from IPython.display import display
import plotly.express as px

# %%
# Cargar archivo de cervezas
df = pd.read_csv("C:\\Users\\angel\\OneDrive\\Documentos\\Data_Analysis\\Proyectos\\Beer\\beer_styles_todos.csv")

# %%
# Explorar los datos
print(df.head())
print(df.info())
print(df.describe())
# Out:
#               estilo                                                url  \
# 0  American Pale Ale  https://www.beer-analytics.com/styles/pale-ame...
# 1     American Lager  https://www.beer-analytics.com/styles/standard...
# 2          Weissbier  https://www.beer-analytics.com/styles/german-w...
# 3        Irish Stout  https://www.beer-analytics.com/styles/irish-be...
# 4       American IPA  https://www.beer-analytics.com/styles/ipa/amer...
#
#            era             origin fermentation color strength     taste  \
# 0        Craft      North America          Top  Pale   Normal    Bitter
# 1  Traditional   🇺🇸 United States       Bottom  Pale   Normal  Balanced
# 2  Traditional  🇪🇺 Central Europe          Top  Pale   Normal     Malty
# 3  Traditional         🇮🇪 Ireland          Top  Dark   Normal    Bitter
# 4        Craft      North America          Top  Pale     High    Bitter
#
#    abv_min_%  abv_max_%  abv_prom_%  ibu_min  ibu_max  ibu_prom  \
# ...

# %%
# Seleccionar columnas de interés
datos_cervezas = df[['estilo', 'era', 'origin', 'fermentation', 'color', 'strength', 'taste', 'ibu_prom', 'abv_prom_%']]
print(datos_cervezas.value_counts())
# Out:
# estilo              era          origin            fermentation  color  strength  taste     ibu_prom  abv_prom_%
# Altbier             Traditional  🇩🇪 Germany        Top           Amber  Normal    Bitter    37.5      4.90          1
# Festbier            Traditional  🇩🇪 Germany        Bottom        Pale   Normal    Malty     21.5      6.05          1
# Oatmeal Stout       Traditional  🇬🇧 Great Britain  Top           Dark   Normal    Balanced  32.5      5.05          1
# Märzen              Traditional  🇩🇪 Germany        Bottom        Amber  Normal    Malty     21.0      5.95          1
# Munich Helles       Traditional  🇩🇪 Germany        Bottom        Pale   Normal    Malty     19.0      5.05          1
#                                                                                                                    ..
# Brut IPA            Craft        North America     Top           Pale   High      Bitter    25.0      6.75          1
# ...
